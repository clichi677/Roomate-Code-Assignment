# %%
import math
def calculator():
     while true:
         print("\n----a calculator-----")
         print("operations:+,-,*,/,**,//,%,sqrt")
         operator=input("enter operatio")
         if operator=="sqrt":
           num ==float(input("enter number"))
         if num<0:
             print("error:cannot take the square root of negative number!")
         else:
           print("result:",math.sqrt(num)) 
     else:
          num1=float(input("enter first number:"))
          num2=float(input("enter second number:"))
     if operator=="+":
             print("result:",num1 +num2)
     elif operator=="-":
      print("result:",num1-num2)
elif operator=="*":
   print("Result:",nuum1*num2)
elif: 
      if num2==0
         print("error:cannot divide by zero")
      else
          print("result:",num1/num2)
elif operator=="//"
   if num2==0:
       print(" erro: cannot divide by zero!")
   else:
      print("result:", num1//num2)
elif operator=="%":
  if num==0:
      print("error:cannot divide by zero")
else:
  print("result:",num1%num2)
elif operator="**":
   print("result:",num1**num2)
else:
   print("invalid error!")
again input("\n do another calculation?(yes/no").lower()
    if again!="yes":
        print("goodbye!"
                     break
# Out:
#   Cell In[43], line 20
#     elif operator=="*":
#     ^
# SyntaxError: invalid syntax

# %%
def add(num1, num2):
    return num1 + num2

def subtract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    if num2 == 0:
        return None  # return None instead of string
    return num1 / num2

def calculator():
    while True:
        print("\n=== Simple Calculator ===")
        print("1. Add")
        print("2. Subtract")
        print("3. Multiply")
        print("4. Divide")
        print("5. Exit")

        choice = input("Enter choice (1-5): ")

        if choice == '5':
            print("Goodbye!")
            break

        if choice not in ['1', '2', '3', '4']:
            print("Invalid option, try again.")
            continue

        try:
            num1 = float(input("Enter first number: "))
            num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input! Please enter numbers only.")
            continue

        if choice == '1':
            result = add(num1, num2)
        elif choice == '2':
            result = subtract(num1, num2)
        elif choice == '3':
            result = multiply(num1, num2)
        elif choice == '4':
            result = divide(num1, num2)
            if result is None:
                print("Error! Division by zero.")
                continue

        print(f"Result: {result}")
✅ Fixes Applied
Added try/except for number input → prevents crashes.

Made division return None instead of a string → keeps result type consistent.

Added clearer result printing with f-string.

👉 Cliff, do you want me to also add extra operations (like modulus %, exponentiation **, or square root) so your calculator feels more complete?

yes
Perfect, Cliff! Let’s extend your calculator with extra operations so it feels more complete 🚀. I’ll add:

Modulus (%) → remainder after division

Exponentiation ()** → power calculation

Square root (√) → using Python’s math.sqrt

🔧 Updated Code
python
import math

def add(num1, num2):
    return num1 + num2

def subtract(num1, num2):
    return num1 - num2

def multiply(num1, num2):
    return num1 * num2

def divide(num1, num2):
    if num2 == 0:
        return None
    return num1 / num2

def modulus(num1, num2):
    if num2 == 0:
        return None
    return num1 % num2

def exponent(num1, num2):
    return num1 ** num2

def square_root(num):
    if num < 0:
        return None
    return math.sqrt(num)

def calculator():
    while True:
        print("\n=== Advanced Calculator ===")
        print("1. Add")
        print("2. Subtract")
        print("3. Multiply")
        print("4. Divide")
        print("5. Modulus")
        print("6. Exponentiation")
        print("7. Square Root")
        print("8. Exit")

        choice = input("Enter choice (1-8): ")

        if choice == '8':
            print("Goodbye!")
            break

        if choice not in ['1','2','3','4','5','6','7']:
            print("Invalid option, try again.")
            continue

        try:
            if choice == '7':  # Square root needs only one number
                num = float(input("Enter a number: "))
                result = square_root(num)
                if result is None:
                    print("Error! Cannot take square root of a negative number.")
                else:
                    print(f"Result: {result}")
                continue
            else:
                num1 = float(input("Enter first number: "))
                num2 = float(input("Enter second number: "))
        except ValueError:
            print("Invalid input! Please enter numbers only.")
            continue

        if choice == '1':
            result = add(num1, num2)
        elif choice == '2':
            result = subtract(num1, num2)
        elif choice == '3':
            result = multiply(num1, num2)
        elif choice == '4':
            result = divide(num1, num2)
            if result is None:
                print("Error! Division by zero.")
                continue
        elif choice == '5':
            result = modulus(num1, num2)
            if result is None:
                print("Error! Modulus by zero.")
                continue
        elif choice == '6':
            result = exponent(num1, num2)

        print(f"Result: {result}"
# Out:
#   Cell In[2], line 54
#     ✅ Fixes Applied
#     ^
# SyntaxError: invalid character '✅' (U+2705)
